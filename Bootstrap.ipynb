# %%
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.style.use('fivethirtyeight')

import statistics
import statsmodels.stats.api as sms
from tqdm.notebook import tqdm
from scipy.stats import ttest_ind

# %%
retention1_hist = pd.read_csv('report.csv',sep=';', encoding='latin-1')
retention1_hist.head()
# Out:
#    ret1
# 0  44.5
# 1  44.5
# 2  44.9
# 3  45.1
# 4  45.1

# %%
retention = retention1_hist.ret1

# %%
retention
# Out:
# 0       44.5
# 1       44.5
# 2       44.9
# 3       45.1
# 4       45.1
#         ...
# 1310    56.0
# 1311    56.1
# 1312    56.4
# 1313    56.8
# 1314    57.3
# Name: ret1, Length: 1315, dtype: float64

# %%
data=[retention.sample(5000,replace=True).mean() for _ in range(10000)]

# %%
sns.histplot(data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
#проверям выборочные средние на нормальность
import pylab 
import scipy.stats as stats

stats.probplot(data, dist="norm", plot=pylab)
pylab.show()
